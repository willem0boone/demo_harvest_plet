# %% [markdown]
# # Test OSPAR COMP areas

# %% [markdown]
# This code demonstrates how to use the ospar_comp functionality in the harvest_plet package. The OSPAR zones are used to perform spatial filters in the PLET requests.

# %% [markdown]
# ### Install the pacakge

# %%
import sys

# %% [markdown]
# If you want to reinstall, first remove and then install again.

# %%
# !{sys.executable} -m pip uninstall -y harvest_plet
# Out:
# Found existing installation: harvest_plet 0.1.0
# Uninstalling harvest_plet-0.1.0:
#   Successfully uninstalled harvest_plet-0.1.0

# %%
# !{sys.executable} -m pip install --quiet "git+https://github.com/willem0boone/harvest_plet#egg=harvest_plet"
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: C:\Users\willem.boone\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %%
import harvest_plet
print(harvest_plet.__version__)
# Out:
# 0.1.0

# %%
from harvest_plet import ospar_comp
comp_regions = ospar_comp.OSPARRegions()

# %% [markdown]
# ### Get COMP area IDs

# %%
id_list = comp_regions.get_all_ids()

for item in id_list:
    print(item)
# Out:
# CFR
# CCTI
# ATL
# SHPM
# CNOR1
# CNOR2
# CNOR3
# DB
# KD
# GBC
# ADPM
# EMPM
# THPM
# HPM
# ECPM1
# NT
# SNS
# ECPM2
# IS2
# GBSW
# SPM
# NNS
# CWM
# LBPM
# GDPM
# CUKC
# CWMTI
# SCHPM1
# ELPM
# SCHPM2
# MPM
# RHPM
# OC
# ENS
# ASS
# CIRL
# CUK1
# IS1
# IRS
# KC
# SK
# SS
# LPM
# GBCW
# NAAP2
# NAAO1
# NAAPF
# NAAC3
# NAAC2
# NAAC1A
# NAAC1B
# NAAC1C
# NAAC1D
# SAAP2
# SAAOC
# SAAP1
# SAAC1
# SAAC2
# OWCO
# CWBC
# OWBO
# CWAC
# OWAO
# CWCC

# %% [markdown]
# ### Plot single COMP area

# %%
comp_regions.plot_map("SNS")

# %% [markdown]
# ### Plot all COMP areas

# %%
comp_regions.plot_map()

# %% [markdown]
# ### Test WKT

# %%
my_wkt = comp_regions.get_wkt("SNS")
print(my_wkt)
# Out:
# MULTIPOLYGON (((-0.05 54.1333333, 0.15 54.2, 0.3092579 54.0565705, 0.4425077 53.9233206, 0.5567219 53.8709725, 0.6625 53.8083333, 0.6875 53.8083333, 0.694787 53.8022608, 0.7875 53.725, 0.8125 53.7083333, 0.8875 53.7916667, 0.9125 53.7916667, 0.9375 53.7916667, 0.9875 53.775, 1.0625 53.7916667, 1.0875 53.7916667, 1.1625 53.7916667, 1.1875 53.8083333, 1.2625 53.8916667, 1.2875 53.8916667, 1.3125 53.8916667, 1.3375 53.8916667, 1.3875 53.875, 1.4125 53.875, 1.4375 53.875, 1.4625 53.875, 1.5125 53.8916667, 1.5375 53.8916667, 1.5625 53.8916667, 1.5875 53.8916667, 1.6125 53.8916667, 1.6625 53.9083333, 1.7125 53.925, 1.8125 53.9416667, 1.8375 53.9416667, 1.8875 53.925, 1.9125 53.925, 1.9375 53.925, 1.9625 53.925, 1.9875 53.925, 2.0375 53.9416667, 2.0875 53.9583333, 2.1125 53.9583333, 2.1375 53.9583333, 2.2125 53.9083333, 2.2375 53.8916667, 2.2625 53.875, 2.2875 53.8583333, 2.3375 53.8416667, 2.3625 53.825, 2.3875 53.825, 2.4375 53.8083333, 2.4625 53.8083333, 2.5125 53.825, 2.5375 53.825, 2.5625 53.825, 2.6375 53.7416667, 2.6625 53.725, 2.6875 53.6916667, 2.691998 53.6886693, 2.7125 53.675, 2.7375 53.6583333, 2.7875 53.6416667, 2.8375 53.625, 2.8875 53.6083333, 2.9375 53.5916667, 2.9891891 53.575, 2.9892328 53.575, 3.0125 